# %% [markdown]
# # Final benchmark

# %%
import pandas as pd,time
start=time.perf_counter(); df=pd.read_csv('../data/processed/workforce_intelligence_final.csv'); elapsed=time.perf_counter()-start
print({'rows':len(df),'columns':len(df.columns),'high_risk':int((df.Attrition_Risk_Score>=.7).sum()),'load_seconds':round(elapsed,4)})
