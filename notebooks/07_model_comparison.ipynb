# %% [markdown]
# # Model comparison
# Compare models on the same leakage-safe attrition dataset and split.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
# The reproducible production pipeline is in scripts/train_attrition.py; this notebook is an experiment template.
df=pd.read_csv('../data/raw/employee_attrition.csv')
print(df.shape)
print('Use the training script for the final preprocessing + model artifact.')
# Out:
# (1470, 35)
# Use the training script for the final preprocessing + model artifact.
