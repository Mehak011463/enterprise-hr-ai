# %% [markdown]
# # Baseline model
# Logistic regression is retained as an explainable benchmark. The production artifact is the XGBoost pipeline saved by `scripts/train_attrition.py`.

# %%
from sklearn.linear_model import LogisticRegression
print('Baseline specification: LogisticRegression(class_weight="balanced", max_iter=1000)')
print('Production training: python scripts/train_attrition.py')
# Out:
# Baseline specification: LogisticRegression(class_weight="balanced", max_iter=1000)
# Production training: python scripts/train_attrition.py
