# %% [markdown]
# # HR policy retrieval
# The MVP uses TF-IDF retrieval over policy passages. It returns grounded passages rather than inventing policy answers.

# %%
import sys; sys.path.append('..')
from app.services.policy_service import PolicyService
svc=PolicyService()
print(svc.search('training budget'))
